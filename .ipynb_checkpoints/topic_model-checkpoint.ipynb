# %%
#!pip install gensim
from gensim import models, corpora
import pandas as pd
import pyLDAvis.gensim

# %%
def prep_corpus(fname):
    "reads in file, makes a gensim-usable corpus out of it"

    with open(fname, 'r') as f:
        docs_full = f.readlines()

    docs = [x.split('\t')[1].split() for x in docs_full]
    for doc in docs:
        while '<NUMBER>' in doc:
            doc.remove('<NUMBER>')
        while 'patient' in doc:
            doc.remove('patient')
        while 'cell' in doc:
            doc.remove('cell')

    dictionary = corpora.Dictionary(docs)
    corpus = [dictionary.doc2bow(doc) for doc in docs]

    return corpus, dictionary, docs


def prep_corpus_csv(fname):
    "reads in file, makes a gensim-usable corpus out of it"

    d = pd.read_csv(fname)
        
    docs = []
    for i in range(len(d.index)):
        docs.append(d.iloc[i,2].split())
    
    for doc in docs:
        while '<NUMBER>' in doc:
            doc.remove('<NUMBER>')
        while 'patient' in doc:
            doc.remove('patient')
        while 'cell' in doc:
            doc.remove('cell')

    dictionary = corpora.Dictionary(docs)
    corpus = [dictionary.doc2bow(doc) for doc in docs]

    return corpus, dictionary, docs

# %%
corp, dictionary, docs = prep_corpus_csv('sampledata.csv')
corp2, dictionary2, docs2 = prep_corpus('pubmed_subset_13.tsv')

# %%
lda_model = models.LdaModel(corpus=corp, 
 num_topics=6, 
 id2word=dictionary, 
 distributed=False, 
 chunksize=2000, 
 passes=5, 
 update_every=1, 
 alpha='auto', 
 eta=None, 
 decay=0.5, 
 offset=1.0, 
 eval_every=10, 
 iterations=50, 
 gamma_threshold=0.001, 
 minimum_probability=0.01, 
 random_state=1, 
 ns_conf=None, 
 minimum_phi_value=0.01, 
 per_word_topics=False, 
 callbacks=None)

# %%
lda_visualization = pyLDAvis.gensim.prepare(lda_model, corp, dictionary, sort_topics=False)
pyLDAvis.display(lda_visualization)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el227181403106276581921648944456"></div>
# <script type="text/javascript">
#
# var ldavis_el227181403106276581921648944456_data = {"mdsDat": {"x": [-0.055781337276778635, 0.1079357046116369, 0.022845406099940787, -0.030710058811465428, -0.030354612400131053, -0.013935102223202562], "y": [-0.02683662235607973, 0.032116170814258695, -0.0890614530213761, 0.03231037070173136, 0.0742595037002295, -0.02278796983876372], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [18.851722060930612, 10.486077104609507, 15.291214039785075, 22.235661723503032, 17.010993033739616, 16.124332037432158]}, "tinfo": {"Term": ["gut", "microbiota", "gene", "HPV", "protein", "PrEP", "microbial", "strain", "microbiome", "TBI", "dose", "infant", "woman", "care", "risk", "intestinal", "de", "injury", "host", "ART", "antibody", "liver", "HIV", "tumor", "child", "report", "feed", "colonic", "female", "NAFLD", "D3", "ICP", "cebranopadol", "C8mim", "mir-1301", "VMMC", "super", "rtms", "RT", "USD", "USVs", "spirituality", "tpa", "FN", "dextrose", "SMS", "NOP", "Jordan", "facial", "DILI", "worm", "EVG", "KLF6", "APAP", "IVF", "Lebanon", "PK", "EAAC1", "chitosan", "tick", "HPV", "OH", "PrEP", "rotavirus", "sirna/np", "AHT", "DENV", "CTP", "agonist", "monitoring", "mir-221", "cost", "peer", "care", "adherence", "receptor", "rehabilitation", "visit", "follow-up", "year", "vaccine", "fibrosis", "cesarean", "screen", "model", "rat", "health", "service", "injury", "drug", "HCV", "HIV", "woman", "CI", "TBI", "viral", "liver", "level", "age", "treatment", "delivery", "disease", "factor", "infection", "intervention", "human", "virus", "response", "rate", "clinical", "expression", "Rubisco", "NOI", "ATRA", "Alb-NP-EGCG", "RDX", "SS", "HIV-2", "HSV-2", "NAT", "HSV-1", "los", "brachytherapy", "TBX20", "la", "enucleation", "EVG/COB/TDF/FTC", "EBR/GZR", "ambrisentan", "fossa", "maxillary", "HVJ-E", "HEU", "del", "literacy", "tuberculous", "Ghana", "col\u00f3nica", "e-gp41", "DREAMS", "salivary", "colonic", "el", "descompresi\u00f3n", "de", "tratamiento", "SBP", "LPS", "decompression", "endometrial", "microbiota", "intestinal", "resilience", "angiogenesis", "host", "microbial", "gut", "female", "infant", "treatment", "mouse", "bacterial", "HIV", "immunization", "response", "injury", "vaccine", "woman", "microbiome", "acid", "death", "young", "infection", "CT", "tumor", "level", "antibody", "child", "follow", "drug", "year", "immune", "day", "factor", "TBI", "disease", "age", "expression", "time", "ICI", "NCH", "suicide", "overload", "taste", "TVS", "mantram", "HGSNAT", "PCR-DB", "regorafenib", "AEs", "RCAN1.4", "PTSD", "MELD", "Vpr", "lactamase", "A\u03b2", "glyburide", "SAL", "antithrombin", "AA", "controller", "rechallenge", "BCG", "anti-il-10", "HER3", "A\u03b2pE3", "GLU", "Vit", "NSI", "EN", "visual", "MPS", "onabotulinumtoxina", "PN", "Eimeria", "HER2", "coronavirus", "iron", "CHA", "MTBI", "hyponatremia", "feed", "exception", "dose", "EGFR", "BC", "report", "blood", "liver", "resistance", "ART", "device", "therapy", "evidence", "tumor", "day", "receive", "case", "antibody", "diet", "CI", "HIV", "level", "energy", "treatment", "safety", "cancer", "human", "month", "infection", "sample", "week", "response", "TBI", "clinical", "decrease", "virus", "participant", "disease", "vaccine", "change", "reduce", "HCMV", "measles", "PaCa", "CVID", "AHB", "peanut", "A3F", "IRIS", "PLCE1", "DOR", "walnut", "preconception", "resect", "GPRC5a", "OT", "NGF", "EC2", "C-glycosyl", "Vif", "agalactiae", "DHPG", "\u03b2-cell", "IRD", "flavone", "Ca2+", "tau", "AIT", "consensus", "furin", "NGS", "EAC", "fracture", "cognitive", "sexual", "IBD", "LTBI", "interface", "stigma", "TBI", "sequence", "chronic", "disease", "genome", "risk", "genotype", "prevention", "clinical", "MSM", "HIV", "brain", "review", "score", "model", "pain", "intervention", "health", "treatment", "provide", "quality", "gene", "system", "microbiome", "life", "genetic", "influence", "infection", "factor", "outcome", "research", "individual", "mouse", "data", "development", "target", "va ...

# %%
lda_model_same = lda_model = models.LdaModel(corpus=corp, 
 num_topics=6, 
 id2word=dictionary, 
 distributed=False, 
 chunksize=2000, 
 passes=5, 
 update_every=1, 
 alpha='auto', 
 eta=None, 
 decay=0.5, 
 offset=1.0, 
 eval_every=10, 
 iterations=50, 
 gamma_threshold=0.001, 
 minimum_probability=0.01, 
 random_state=2, 
 ns_conf=None, 
 minimum_phi_value=0.01, 
 per_word_topics=False, 
 callbacks=None)

# %%
df, wordlist = lda_model.diff(lda_model_same)

# %%
df = pd.DataFrame(df)
df
# Out:
#           0         1         2         3         4         5
# 0  0.000000  0.964302  0.955672  0.940176  0.954978  1.000000
# 1  0.804100  0.000000  0.836121  0.831595  0.817461  0.847809
# 2  0.830991  0.837529  0.000000  0.747356  0.800718  0.795875
# 3  0.844530  0.851702  0.780103  0.000000  0.836585  0.825798
# 4  0.790973  0.805307  0.774175  0.769585  0.000000  0.796840
# 5  0.821110  0.807799  0.767472  0.743470  0.808480  0.000000

# %%
wordlist = pd.DataFrame(wordlist)
wordlist.iloc[1,0]
# Out:
# [['expression',
#   'health',
#   'provide',
#   'response',
#   'TBI',
#   'development',
#   'year',
#   'system',
#   'mechanism',
#   'injury'],
#  ['acid',
#   'CI',
#   'viral',
#   'range',
#   'case',
#   'receptor',
#   'HCV',
#   'scan',
#   'characteristic',
#   'deliver']]

# %%
lda_model2 = lda_model = models.LdaModel(corpus=corp2, 
 num_topics=6, 
 id2word=dictionary2, 
 distributed=False, 
 chunksize=2000, 
 passes=5, 
 update_every=1, 
 alpha='auto', 
 eta=None, 
 decay=0.5, 
 offset=1.0, 
 eval_every=10, 
 iterations=50, 
 gamma_threshold=0.001, 
 minimum_probability=0.01, 
 random_state=2, 
 ns_conf=None, 
 minimum_phi_value=0.01, 
 per_word_topics=False, 
 callbacks=None)

# %%
lda_visualization = pyLDAvis.gensim.prepare(lda_model2, corp2, dictionary2, sort_topics=False)
pyLDAvis.display(lda_visualization)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el227181403107620607524658789867"></div>
# <script type="text/javascript">
#
# var ldavis_el227181403107620607524658789867_data = {"mdsDat": {"x": [-0.1168387935414781, -0.11979872556504154, 0.1748481778099896, -0.11914491431015513, 0.008342117450979044, 0.17259213815570607], "y": [-0.19152427588461943, 0.03344539965491874, 0.035882530126846335, 0.1140143476769357, 0.07593705587729434, -0.06775505745137625], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [18.289587553594288, 15.883621904688571, 19.752767062416428, 6.384830487752947, 13.740767537755453, 25.948425453792318]}, "tinfo": {"Term": ["expression", "health", "gene", "protein", "care", "cancer", "mouse", "age", "year", "CI", "specie", "risk", "outcome", "child", "surgery", "pathway", "clinical", "woman", "month", "case", "social", "treatment", "mechanism", "surface", "intervention", "concentration", "score", "pain", "mortality", "drug", "autophagy", "upregulated", "apoptosis", "NF-\u03baB", "mirnas", "overexpression", "GBM", "downregulated", "IL-6", "EVs", "cytokine", "TNF-\u03b1", "knockdown", "downregulation", "interleukin", "neuroprotective", "EMT", "BBB", "H2O2", "Treg", "blotting", "AR", "circadian", "VEGF", "PI3K", "\u03b2-catenin", "upregulation", "CD8", "apoptotic", "LS", "expression", "mrna", "transcription", "blot", "mouse", "RNAs", "proliferation", "phosphorylation", "silence", "neutrophil", "inhibit", "signaling", "regulator", "promoter", "immune", "regulate", "pathway", "receptor", "mitochondrial", "gene", "induce", "express", "activation", "protein", "macrophage", "assay", "diet", "inhibition", "vitro", "rat", "vaccine", "virus", "role", "mechanism", "cellular", "target", "growth", "human", "level", "activity", "response", "stress", "therapeutic", "tissue", "cancer", "tumor", "potential", "disease", "factor", "treatment", "function", "decrease", "model", "reduce", "bond", "graphene", "lithium", "grain", "disulfide", "microstructure", "g-1", "osteogenic", "phthalate", "lignin", "ma", "IVM", "Ca", "C1", "MPS", "nonlinear", "officinalis", "dope", "anisotropy", "synapsis", "proteome", "porosity", "polyurethane", "ketone", "conformation", "MPs", "ash", "prion", "mineralization", "CBD", "testosterone", "NMR", "quantum", "storage", "chemistry", "ppm", "actuator", "energy", "derivative", "redox", "electron", "atomic", "ligand", "ion", "structure", "oxidation", "surface", "kinetics", "acid", "property", "material", "calculation", "structural", "particle", "\u00b0c", "channel", "fluorescence", "chemical", "formation", "dynamic", "mode", "application", "temperature", "simulation", "stability", "compound", "metabolite", "molecular", "interaction", "water", "complex", "system", "concentration", "state", "protein", "different", "form", "process", "bone", "change", "condition", "provide", "model", "tissue", "activity", "potential", "function", "new", "mechanism", "level", "base", "nurse", "attitude", "nursing", "student", "education", "violence", "respondent", "household", "well-being", "colonoscopy", "motivation", "stone", "cannabis", "educational", "engagement", "youth", "teacher", "faculty", "tick", "socioeconomic", "curriculum", "private", "peer", "workplace", "burnout", "amyloidosis", "teach", "resident", "AOR", "GDM", "social", "policy", "mental", "school", "caregiver", "healthcare", "interview", "health", "rural", "psychological", "public", "provider", "survey", "service", "worker", "professional", "skill", "anxiety", "care", "practice", "program", "depression", "questionnaire", "people", "home", "HIV", "participant", "prevalence", "intervention", "woman", "physical", "experience", "child", "Health", "age", "medical", "adult", "research", "measure", "risk", "year", "need", "data", "time", "factor", "relationship", "CI", "individual", "population", "association", "report", "change", "level", "provide", "model", "rate", "disease", "rm", "ACS", "PCL", "sludge", "SiO2", "palate", "QDs", "probiotic", "Pt", "emulsifier", "AMR", "MPV", "IgA", "nanocomposite", "nitrate", "CoNPs", "FOG", "leachate", "polyp", "toe", "ciprofloxaci ...

# %%
df2, wordlist2 = lda_model.diff(lda_model2)

# %%
df2 = pd.DataFrame(df2)
df2
# Out:
#           0         1         2         3         4         5
# 0  0.000000  0.606706  1.000000  0.764545  0.811079  0.912881
# 1  0.640657  0.000000  0.822754  0.488847  0.584167  0.878897
# 2  0.951692  0.851102  0.000000  0.850408  0.631381  0.602300
# 3  0.817281  0.596190  0.906516  0.000000  0.755259  0.962877
# 4  0.753100  0.569496  0.657047  0.628122  0.000000  0.779699
# 5  0.869571  0.853000  0.589819  0.828014  0.757033  0.000000

# %%
wordlist2 = pd.DataFrame(wordlist2)
wordlist2.iloc[0,0]
# Out:
# [['acid',
#   'treat',
#   'RNA',
#   'express',
#   'tissue',
#   'target',
#   'resistance',
#   'model',
#   'promote',
#   'host'],
#  []]
